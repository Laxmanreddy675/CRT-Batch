# %%
print("gitam",end="@")
print("gitam")
# Out:
# gitam@gitam

# %%
a=10
print(a)
a*10
# Out:
# 10
# 100

# %%
b=10
a+b
# Out:
# 20

# %%
name="gitam"
print(name)
# Out:
# gitam

# %%
address="hyd"
print("univesity name",name,"place",address)
# Out:
# univesity name gitam place hyd

# %%
name+="university"
print(name)
# Out:
# gitamuniversity

# %%
input("")
# Out:
# dfghjkl
# 'dfghjkl'

# %%
input("enter the name")
# Out:
# enter the namelaxman
# 'laxman'

# %%
int(input())
# Out:
# 20
# 20

# %%
a=input()
print(a)
type(a)
# Out:
# 20
# 20
# str

# %%
b=int(input())
type(b)
# Out:
# 20
# int

# %%
a=int(input("enter the value"))
b=input("enter the value")
a
b
print(type(a))
print(type(b))
# Out:
# enter the value20
# enter the valuex
# <class 'int'>
# <class 'str'>

# %%
x=1
y=12.4
z="true"
a="laxman"
print(type(x),type(y),type(z),type(a))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'str'>

# %%
z=1+2j
print(type(z))
# Out:
# <class 'complex'>

# %%
x=1
x=complex(x)
print(x)
# Out:
# (1+0j)

# %%
x=1.1
x=complex(x)
print(x)
# Out:
# (1.1+0j)

# %%
c=complex(2,4)
print(c)
# Out:
# (2+4j)

# %%
b=True
print(type(b))
# Out:
# <class 'bool'>

# %%
x=10
x=str(x)
print(type(x))
# Out:
# <class 'str'>

# %%
x=10
print(type(x))
x=float(x)
print(type(x))
print(x)
# Out:
# <class 'int'>
# <class 'float'>
# 10.0

# %% [markdown]
# "X

# %%
print(4+5)
print(4-5)
print(4*5)
print(4/2)
print(4//2)
print(4%2)
# Out:
# 9
# -1
# 20
# 2.0
# 2
# 0

# %%
a=20
b=60
print(a>=10 and a<=15)
# Out:
# False

# %%
a=20
b=60
print(a>=10 or a<=15)
# Out:
# True

# %%
a=10
b=20
x=a>b
print(x)
# Out:
# False

# %%
print(not x)
# Out:
# True

# %%
str1="abc"
print("c" in str1)
# Out:
# True

# %%
str1="abc"
print("d" not in str1)
print("d"in str1)
# Out:
# True
# False

# %%
a=10
if a:
  print("yes")
# Out:
# yes

# %%
a=int(input("enter the no"))
if a%2==0:
  print("even")
else:
  print("odd")
# Out:
# enter the no10
# even

# %%
a=int(input("enter"))

# %% [markdown]
# # if statements
# ### if condition:(body)
# ### elif condition:(body)
# ### else:(body)

# %%
n=int(input("enter a no"))
if ((n%4==0 and n%100!=0) or n%400==0):
   print("it is a leap year")
else:
  print("it is not leap year")
# Out:
# enter a no2019
# it is not leap year
